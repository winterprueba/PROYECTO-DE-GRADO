# %% [markdown]
# Definir rutas y cargar las tablas de Risaralda

# %%
import pandas as pd

BASE_PATH = "ETAPA 1 - CONSTRUCCIÓN BASE DE DATOS/DATA CENSO/66_Risaralda_CSV/"

paths = {
    "PERSONAS": BASE_PATH + "CNPV2018_5PER_A2_66.CSV",
    "HOGARES": BASE_PATH + "CNPV2018_2HOG_A2_66.CSV",
    "VIVIENDAS": BASE_PATH + "CNPV2018_1VIV_A2_66.CSV",
    "FALLECIDOS": BASE_PATH + "CNPV2018_3FALL_A2_66.CSV",
    "MGN": BASE_PATH + "CNPV2018_MGN_A2_66.CSV",
}

def read_df(path):
    # Lectura de archivos CSV del CNPV
    return pd.read_csv(path, sep=",", encoding="latin-1", low_memory=False)

def filter_pereira(df):
    dpto = df["U_DPTO"].astype(str).str.zfill(2)
    mpio = df["U_MPIO"].astype(str).str.zfill(3)
    return df[(dpto == "66") & (mpio == "001")].copy()

dfs_per = {}

for name, path in paths.items():
    df = read_df(path)
    df_per = filter_pereira(df)
    dfs_per[name] = df_per
    print(name, df.shape, "-> Pereira:", df_per.shape)
# Out:
# PERSONAS (839597, 48) -> Pereira: (409670, 48)
# HOGARES (278133, 13) -> Pereira: (139050, 13)
# VIVIENDAS (342396, 30) -> Pereira: (173564, 30)
# FALLECIDOS (6243, 11) -> Pereira: (2931, 11)
# MGN (342396, 14) -> Pereira: (173564, 14)

# %% [markdown]
# Filtrar Pereira desde Risaralda
# Qué hacemos: como el censo viene por departamento, primero cargamos todo Risaralda (66) y luego filtramos solo el municipio Pereira (001).
#
# Por qué normalizamos (zfill): a veces los códigos vienen como 1 en vez de "001", entonces los “rellenamos” para que el filtro sea robusto.

# %% [markdown]
# Normalizar llaves para que los merges no fallen

# %%
def norm_keys(df):
    df["U_DPTO"] = df["U_DPTO"].astype(str).str.zfill(2)
    df["U_MPIO"] = df["U_MPIO"].astype(str).str.zfill(3)
    df["COD_ENCUESTAS"] = df["COD_ENCUESTAS"].astype(str)
    df["U_VIVIENDA"] = df["U_VIVIENDA"].astype(str)
    return df

for k in dfs_per:
    dfs_per[k] = norm_keys(dfs_per[k])

# %%
# --- deduplicación defensiva (evita multiplicaciones artificiales) ---
k_viv = ["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA"]
k_hog = ["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA","H_NROHOG"]
k_mgn = ["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA"]

dfs_per["VIVIENDAS"] = dfs_per["VIVIENDAS"].drop_duplicates(subset=k_viv, keep="first")
dfs_per["HOGARES"]   = dfs_per["HOGARES"].drop_duplicates(subset=k_hog, keep="first")
dfs_per["MGN"]       = dfs_per["MGN"].drop_duplicates(subset=k_mgn, keep="first")

# %% [markdown]
# Consolidar: PERSONAS → HOGARES → VIVIENDAS → MGN
#
#
# Qué hacemos: construimos una sola base maestra por persona, pegándole (en cascada) la info del hogar, la vivienda y la geografía.

# %%
df_PH = dfs_per["PERSONAS"].merge(
    dfs_per["HOGARES"],
    left_on=["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA","P_NROHOG"],
    right_on=["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA","H_NROHOG"],
    how="left",
    suffixes=("", "_H")
)

df_PH.shape
# Out:
# (409670, 56)

# %%
df_PHV = df_PH.merge(
    dfs_per["VIVIENDAS"],
    on=["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA"],
    how="left",
    suffixes=("", "_V")
)

df_PHV.shape
# Out:
# (409670, 81)

# %%
df_master = df_PHV.merge(
    dfs_per["MGN"],
    on=["U_DPTO","U_MPIO","UA_CLASE","COD_ENCUESTAS","U_VIVIENDA"],
    how="left"
)

df_master.shape
# Out:
# (409670, 90)

# %% [markdown]
# Chequeos rápidos de calidad

# %% [markdown]
# Columnas con demasiados nulos

# %%
df_master.isna().mean().sort_values(ascending=False).head(15)
# Out:
# UVA1_TIPOTER         1.000000
# UVA2_CODTER          1.000000
# PA22_COD_KUMPA       0.999980
# PA12_CLAN            0.999980
# PA21_COD_VITSA       0.999980
# PB1_QOTRAS_LENG      0.999243
# PA1_ENTIENDE         0.996824
# PA11_COD_ETNIA       0.995389
# PA_HABLA_LENG        0.995203
# PB_OTRAS_LENG        0.995203
# UVA1_COD_AREAPROT    0.993275
# L_EXISTEHOG          0.992804
# L_TOT_PERL           0.992804
# L_TIPO_INST          0.992804
# HA_NRO_FALL          0.979891
# dtype: float64

# %% [markdown]
# Seleccionar el núcleo analítico

# %%
geo_cols = [
    "U_DPTO","U_MPIO","UA_CLASE",
    "UA1_LOCALIDAD","U_SECT_URB","U_SECC_URB","U_MZA",
    "COD_DANE_ANM"
]

demo_cols = [
    "P_SEXO","P_EDADR","P_PARENTESCOR"
]

edu_cols = [
    "P_ALFABETA","PA_ASISTENCIA","P_NIVEL_ANOSR"
]

salud_cols = [
    "P_ENFERMO","PA_LO_ATENDIERON","PA1_CALIDAD_SERV"
]

trab_cols = ["P_TRABAJO"]

vivienda_cols = [
    "V_TIPO_VIV",
    "V_MAT_PARED",
    "V_MAT_PISO",
    "VA1_ESTRATO"
]

serv_cols = [
    "VA_EE","VB_ACU","VC_ALC","VD_GAS","VE_RECBAS","VF_INTERNET"
]

hacin_cols = [
    "H_NRO_CUARTOS","H_NRO_DORMIT","HA_TOT_PER"
]

key_cols = ["U_VIVIENDA","P_NROHOG","P_NRO_PER","COD_ENCUESTAS"]

keep_cols = list(set(
    geo_cols + demo_cols + edu_cols + salud_cols +
    trab_cols + vivienda_cols + serv_cols + hacin_cols + key_cols
))

existing = set(df_master.columns)
kept = sorted(existing.intersection(keep_cols))
removed = sorted(existing - set(kept))

print("COLUMNAS QUE SE QUEDAN:", len(kept))
print("COLUMNAS ELIMINADAS:", len(removed))
# Out:
# COLUMNAS QUE SE QUEDAN: 35
# COLUMNAS ELIMINADAS: 55

# %%
import pandas as pd

df_report = pd.DataFrame({
    "columna": kept + removed,
    "estado": ["SE QUEDA"]*len(kept) + ["SE ELIMINA"]*len(removed)
})

df_report["bloque"] = df_report["columna"].map(
    lambda c:
        "Geografía" if c in geo_cols else
        "Demografía" if c in demo_cols else
        "Educación" if c in edu_cols else
        "Salud" if c in salud_cols else
        "Trabajo" if c in trab_cols else
        "Vivienda" if c in vivienda_cols else
        "Servicios" if c in serv_cols else
        "Hacinamiento" if c in hacin_cols else
        "Llaves" if c in key_cols else
        "Otros"
)

# 👇 Tablas separadas como la vez pasada
display(df_report[df_report.estado == "SE QUEDA"].sort_values(["bloque","columna"]))
display(df_report[df_report.estado == "SE ELIMINA"].sort_values(["bloque","columna"]))
# Out:
#              columna    estado        bloque
# 9            P_EDADR  SE QUEDA    Demografía
# 14     P_PARENTESCOR  SE QUEDA    Demografía
# 15            P_SEXO  SE QUEDA    Demografía
# 6      PA_ASISTENCIA  SE QUEDA     Educación
# 8         P_ALFABETA  SE QUEDA     Educación
# 11     P_NIVEL_ANOSR  SE QUEDA     Educación
# 0       COD_DANE_ANM  SE QUEDA     Geografía
# 17     UA1_LOCALIDAD  SE QUEDA     Geografía
# 18          UA_CLASE  SE QUEDA     Geografía
# 19            U_DPTO  SE QUEDA     Geografía
# 20            U_MPIO  SE QUEDA     Geografía
# 21             U_MZA  SE QUEDA     Geografía
# 22        U_SECC_URB  SE QUEDA     Geografía
# 23        U_SECT_URB  SE QUEDA     Geografía
# 2         HA_TOT_PER  SE QUEDA  Hacinamiento
# 3      H_NRO_CUARTOS  SE QUEDA  Hacinamiento
# 4       H_NRO_DORMIT  SE QUEDA  Hacinamiento
# 1      COD_ENCUESTAS  SE QUEDA        Llaves
# 12          P_NROHOG  SE QUEDA        Llaves
# 13         P_NRO_PER  SE QUEDA        Llaves
# 24        U_VIVIENDA  SE QUEDA        Llaves
# 5   PA1_CALIDAD_SERV  SE QUEDA         Salud
# 7   PA_LO_ATENDIERON  SE QUEDA         Salud
# 10         P_ENFERMO  SE QUEDA         Salud
# 26             VA_EE  SE QUEDA     Servicios
# 27            VB_ACU  SE QUEDA     Servicios
# 28            VC_ALC  SE QUEDA     Servicios
# 29            VD_GAS  SE QUEDA     Servicios
# 30         VE_RECBAS  SE QUEDA     Servicios
# 31       VF_INTERNET  SE QUEDA     Servicios
# 16         P_TRABAJO  SE QUEDA       Trabajo
# 25       VA1_ESTRATO  SE QUEDA      Vivienda
# 32       V_MAT_PARED  SE QUEDA      Vivienda
# 33        V_MAT_PISO  SE QUEDA      Vivienda
# 34        V_TIPO_VIV  SE QUEDA      Vivienda
#               columna      estado bloque
# 35   CONDICION_FISICA  SE ELIMINA  Otros
# 36        HA_NRO_FALL  SE ELIMINA  Otros
# 37       H_AGUA_COCIN  SE ELIMINA  Otros
# 38   H_DONDE_PREPALIM  SE ELIMINA  Otros
# 39           H_NROHOG  SE ELIMINA  Otros
# 40        L_EXISTEHOG  SE ELIMINA  Otros
# 41        L_TIPO_INST  SE ELIMINA  Otros
# 42         L_TOT_PERL  SE ELIMINA  Otros
# 43     PA11_COD_ETNIA  SE ELIMINA  Otros
# 44          PA12_CLAN  SE ELIMINA  Otros
# 45       PA1_ENTIENDE  SE ELIMINA  Otros
# 46      PA1_GRP_ETNIC  SE ELIMINA  Otros
# 47       PA1_MES_UHNV  SE ELIMINA  Otros
# 48           PA1_THFC  SE ELIMINA  Otros
# 49           PA1_THNV  SE ELIMINA  Otros
# 50           PA1_THSV  SE ELIMINA  Otros
# 51     PA21_COD_VITSA  SE ELIMINA  Otros
# 52     PA22_COD_KUMPA  SE ELIMINA  Otros
# 53       PA2_ANO_UHNV  SE ELIMINA  Otros
# 54           PA2_HFCH  SE ELIMINA  Otros
# 55           PA2_HNVH  SE ELIMINA  Otros
# 56           PA2_HSVH  SE ELIMINA  Otros
# 57           PA3_HFCM  SE ELIMINA  Otros
# 58           PA3_HNVM  SE ELIMINA  Otros
# 59           PA3_HSVM  SE ELIMINA  Otros
# 60      PA_HABLA_LENG  SE ELIMINA  Otros
# 61             PA_HFC  SE ELIMINA  Otros
# 62             PA_HNV  SE ELIMINA  Otros
# 63            PA_HNVS  SE ELIMINA  Otros
# 64         PA_LUG_NAC  SE ELIMINA  Otros
# 65            PA_UHNV  SE ELIMINA  Otros
# 66      PA_VIVIA_1ANO  SE ELIMINA  Otros
# 67     PA_VIVIA_5ANOS  SE ELIMINA  Otros
# 68    PB1_QOTRAS_LENG  SE ELIMINA  Otros
# 69      PB_OTRAS_LENG  SE ELIMINA  Otros
# 70        P_EST_CIVIL  SE ELIMINA  Otros
# 71     P_QUEHIZO_PPAL  SE ELIMINA  Otros
# 72           TIPO_REG  SE ELIMINA  Otros
# 73         TIPO_REG_H  SE ELIMINA  Otros
# 74         TIPO_REG_V  SE ELIMINA  Otros
# 75           UA2_CPOB  SE ELIMINA  Otros
# 76  UVA1_COD_AREAPROT  SE ELIMINA  Otros
# 77       UVA1_TIPOTER  SE ELIMINA  Otros
# 78        UVA2_CODTER  SE ELIMINA  Otros
# 79        UVA_ESTATER  SE ELIMINA  Otros
# 80  UVA_ESTA_AREAPROT  SE ELIMINA  Otros
# 81     UVA_USO_UNIDAD  SE ELIMINA  Otros
# 82        U_EDIFICA_x  SE ELIMINA  Otros
# 83        U_EDIFICA_y  SE ELIMINA  Otros
# 84         U_SECC_RUR  SE ELIMINA  Otros
# 85         U_SECT_RUR  SE ELIMINA  Otros
# 86           VE1_QSEM  SE ELIMINA  Otros
# 87         V_CON_OCUP  SE ELIMINA  Otros
# 88       V_TIPO_SERSA  SE ELIMINA  Otros
# 89          V_TOT_HOG  SE ELIMINA  Otros

# %%
import matplotlib.pyplot as plt

df_report["estado"].value_counts().plot(kind="bar")
plt.title("Columnas retenidas vs eliminadas (Pereira)")
plt.show()

# %% [markdown]
# Master reducido

# %%
df_master_reducido = df_master.loc[:, kept].copy()

print("Original:", df_master.shape)
print("Reducido:", df_master_reducido.shape)
# Out:
# Original: (409670, 90)
# Reducido: (409670, 35)

# %%
df_master_reducido.to_csv(
    "ETAPA 1 - CONSTRUCCIÓN BASE DE DATOS/outputs/pereira_base_consolidada_reducida.csv.gz",
    index=False,
    compression="gzip"
)

print("Archivo guardado")
# Out:
# Archivo guardado
